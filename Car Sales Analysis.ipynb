# %%
import pandas as pd

# %%
import numpy as np

# %%
data1=pd.read_csv(r"/Users/kushagraverma/Desktop/Kushagra Verma/Car Sales Project/1.csv")
data1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data2=pd.read_csv(r"/Users/kushagraverma/Desktop/Kushagra Verma/Car Sales Project/2.csv")
data2
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data3=pd.read_csv(r"/Users/kushagraverma/Desktop/Kushagra Verma/Car Sales Project/3.csv")
data3
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1.rename(columns={'name': 'Company Name'}, inplace=True)
data1
# Out:
#                              Company Name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data2.rename(columns={'name': 'Company Name'}, inplace=True)
data2
# Out:
#                       Company Name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data3.rename(columns={'Make': 'Company Name'}, inplace=True)
data3
# Out:
#        Company Name                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1['Company Name'] = data1['Company Name'].apply(lambda x: x.split()[0])
data1
# Out:
#      Company Name  year  selling_price  km_driven    fuel seller_type  \
# 0          Maruti  2007          60000      70000  Petrol  Individual
# 1           Skoda  2007         135000      50000  Petrol  Individual
# 2           Honda  2012         600000     100000  Diesel  Individual
# 3         Hyundai  2017         250000      46000  Petrol  Individual
# 4          Maruti  2014         450000     141000  Diesel  Individual
# ...           ...   ...            ...        ...     ...         ...
# 4335          BMW  2014         409999      80000  Diesel  Individual
# 4336        Honda  2014         409999      80000  Diesel  Individual
# 4337        Skoda  2009         110000      83000  Petrol  Individual
# 4338        Volvo  2016         865000      90000  Diesel  Individual
# 4339       Maruti  2016         225000      40000  Petrol  Individual
#
#      transmission         owner
# 0          Manual   First Owner
# 1          Manual   First Owner
# ...

# %%
data2['Company Name'] = data2['Company Name'].apply(lambda x: x.split()[0])
data2
# Out:
#      Company Name  year  selling_price  km_driven    fuel seller_type  \
# 0          Maruti  2014         450000     145500  Diesel  Individual
# 1           Skoda  2014         370000     120000  Diesel  Individual
# 2           Honda  2006         158000     140000  Petrol  Individual
# 3         Hyundai  2010         225000     127000  Diesel  Individual
# 4          Maruti  2007         130000     120000  Petrol  Individual
# ...           ...   ...            ...        ...     ...         ...
# 8123      Hyundai  2013         320000     110000  Petrol  Individual
# 8124      Hyundai  2007         135000     119000  Diesel  Individual
# 8125       Maruti  2009         382000     120000  Diesel  Individual
# 8126         Tata  2013         290000      25000  Diesel  Individual
# 8127         Tata  2013         290000      25000  Diesel  Individual
#
#      transmission                 owner     mileage   engine   max_power  \
# ...

# %%
data3['Company Name'] = data3['Company Name'].apply(lambda x: x.split()[0])
data3
# Out:
#      Company Name                                  Model    Price  Year  \
# 0           Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1          Maruti                        Swift DZire VDI   450000  2014
# 2         Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3          Toyota                               Glanza G   799000  2019
# 4          Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...           ...                                    ...      ...   ...
# 2054     Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055      Hyundai                           Eon D-Lite +   275000  2014
# 2056         Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057          BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058     Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1 = data1.drop(['selling_price', 'km_driven'], axis=1)

# %%
data1.columns
# Out:
# Index(['Company Name', 'fuel', 'seller_type', 'transmission', 'owner'], dtype='object')

# %%
data2.columns
# Out:
# Index(['Company Name', 'year', 'selling_price', 'km_driven', 'fuel',
#        'seller_type', 'transmission', 'owner', 'mileage', 'engine',
#        'max_power', 'torque', 'seats'],
#       dtype='object')

# %%
data2 = data2.drop(['year', 'selling_price', 'km_driven','mileage', 'engine',
       'max_power', 'torque', 'seats'],axis=1)

# %%
data2.columns
# Out:
# Index(['Company Name', 'fuel', 'seller_type', 'transmission', 'owner'], dtype='object')

# %%
data3 = data3.drop(['Model', 'Price', 'Year', 'Kilometer', 'Location', 'Color', 'Engine',
       'Max Power', 'Max Torque', 'Drivetrain', 'Length', 'Width', 'Height',
       'Seating Capacity', 'Fuel Tank Capacity'],axis=1)

# %%
data3.columns
# Out:
# Index(['Company Name', 'Fuel Type', 'Transmission', 'Owner', 'Seller Type'], dtype='object')

# %%
data2.rename(columns={'fuel': 'Fuel Type','transmission':'Transmission','seller_type':'Seller Type','owner':"Owner"}, inplace=True)
data2
# Out:
#      Company Name Fuel Type Seller Type Transmission                 Owner
# 0          Maruti    Diesel  Individual       Manual           First Owner
# 1           Skoda    Diesel  Individual       Manual          Second Owner
# 2           Honda    Petrol  Individual       Manual           Third Owner
# 3         Hyundai    Diesel  Individual       Manual           First Owner
# 4          Maruti    Petrol  Individual       Manual           First Owner
# ...           ...       ...         ...          ...                   ...
# 8123      Hyundai    Petrol  Individual       Manual           First Owner
# 8124      Hyundai    Diesel  Individual       Manual  Fourth & Above Owner
# 8125       Maruti    Diesel  Individual       Manual           First Owner
# 8126         Tata    Diesel  Individual       Manual           First Owner
# 8127         Tata    Diesel  Individual       Manual           First Owner
#
# [8128 rows x 5 columns]

# %%
data1.rename(columns={'fuel': 'Fuel Type','transmission':'Transmission','seller_type':'Seller Type','owner':"Owner"}, inplace=True)
data1
# Out:
#      Company Name Fuel Type Seller Type Transmission         Owner
# 0          Maruti    Petrol  Individual       Manual   First Owner
# 1           Skoda    Petrol  Individual       Manual   First Owner
# 2           Honda    Diesel  Individual       Manual   First Owner
# 3         Hyundai    Petrol  Individual       Manual   First Owner
# 4          Maruti    Diesel  Individual       Manual  Second Owner
# ...           ...       ...         ...          ...           ...
# 4335          BMW    Diesel  Individual       Manual  Second Owner
# 4336        Honda    Diesel  Individual       Manual  Second Owner
# 4337        Skoda    Petrol  Individual       Manual  Second Owner
# 4338        Volvo    Diesel  Individual       Manual   First Owner
# 4339       Maruti    Petrol  Individual       Manual   First Owner
#
# [4340 rows x 5 columns]

# %%
print(data1.columns)
print(data2.columns)
print(data3.columns)
# Out:
# Index(['Company Name', 'Fuel Type', 'Seller Type', 'Transmission', 'Owner'], dtype='object')
# Index(['Company Name', 'Fuel Type', 'Seller Type', 'Transmission', 'Owner'], dtype='object')
# Index(['Company Name', 'Fuel Type', 'Transmission', 'Owner', 'Seller Type'], dtype='object')

# %%
reference_columns = data1.columns

data2 = data2[reference_columns]
data3 = data3[reference_columns]


print(data1.columns)
print(data2.columns)
print(data3.columns)
# Out:
# Index(['Company Name', 'Fuel Type', 'Seller Type', 'Transmission', 'Owner'], dtype='object')
# Index(['Company Name', 'Fuel Type', 'Seller Type', 'Transmission', 'Owner'], dtype='object')
# Index(['Company Name', 'Fuel Type', 'Seller Type', 'Transmission', 'Owner'], dtype='object')

# %%
cleaned_data1 = pd.DataFrame(data1)
cleaned_data1.to_csv('cleaned_data1.csv', index=False)

# %%
cleaned_data2 = pd.DataFrame(data2)
cleaned_data2.to_csv('cleaned_data2.csv', index=False)

# %%
cleaned_data3 = pd.DataFrame(data1)
cleaned_data3.to_csv('cleaned_data3.csv', index=False)

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/kushagraverma
